# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import os
current_directory = os.getcwd()
print(current_directory)
# Out:
# C:\Users\rauna\Downloads\Liqour Sales Capstone Project Pitch

# %%
df = pd.read_csv("Iowa_Liquor_Products.csv")

# %%
liquordata = pd.read_csv("Iowa_LiquorSale.csv")
# Out:
# C:\Users\rauna\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35484/3899206845.py in <module>
#       2 import time
#       3 start_time = time.time()
# ----> 4 main()
#       5 print("--- %s seconds ---" % (time.time() - start_time))
#
# NameError: name 'main' is not defined

# %%
liquordata.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0     INV-00459100040  09/21/2016          4879
# 1     INV-00440400005  09/21/2016          2851
# 2     INV-00448600056  09/21/2016          2502
# 3     INV-00479600059  09/22/2016          2633
# 4     INV-00475700065  09/22/2016          2627
#
#                                      Store Name  \
# 0  Sam's Mini Mart / Morningside Ave Sioux City
# 1            CVS / Pharmacy #10282 / Fort Dodge
# 2              Hy-Vee Wine and Spirits / Ankeny
# 3                  Hy-Vee #3 / BDI / Des Moines
# 4                    Hy-Vee Wine and Spirits #1
#
#                           Address        City Zip Code  \
# 0            4218 MORNINGSIDE AVE  Sioux City    51106
# 1              2029 5th Ave South  Fort Dodge    50501
# 2           410 North Ankeny Blvd      Ankeny    50021
# 3                 3221 SE 14th St  Des Moines    50320
# 4  3424 Martin Luther King Jr Pkw  Des Moines    50310
#
# ...

# %%
random_liq_subset = liquordata.sample(n = 1000000)

# %%
#reset index for random selection
random_liq_subset = random_liq_subset.reset_index()

# %%
random_liq_subset
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 4087783         S23086400031  12/23/2014          2959
# 20809284     INV-00970400035  10/17/2016          4203
# 17970027     INV-30270500005  09/16/2020          5590
# 4809606         S26574500077  07/06/2015          2653
# 4849678         S04876100001  04/04/2012          2190
# ...                      ...         ...           ...
# 10174267     INV-19398900002  05/16/2019          4103
# 18412358        S31652800272  04/06/2016          5219
# 9713039         S05455000009  05/09/2012          3400
# 4310616         S10975400030  03/07/2013          2625
# 6785959         S05849700003  06/04/2012          4256
#
#                                     Store Name              Address  \
# 4087783                     Dahl's / Merle Hay  4343 MERLE HAY ROAD
# 20809284           Liquor and Tobacco Outlet /     620 W Bremer Ave
# 17970027  Casey's General Store #1941 / Ankeny  1010 SE Oralabor Rd
# ...

# %% [markdown]
# ## drop "index" column

# %%
random_liq_subset = random_liq_subset.drop('index', axis = 1)

# %%
random_liq_subset
# Out:
#        Invoice/Item Number        Date  Store Number  \
# 0             S23086400031  12/23/2014          2959
# 1          INV-00970400035  10/17/2016          4203
# 2          INV-30270500005  09/16/2020          5590
# 3             S26574500077  07/06/2015          2653
# 4             S04876100001  04/04/2012          2190
# ...                    ...         ...           ...
# 999995     INV-19398900002  05/16/2019          4103
# 999996        S31652800272  04/06/2016          5219
# 999997        S05455000009  05/09/2012          3400
# 999998        S10975400030  03/07/2013          2625
# 999999        S05849700003  06/04/2012          4256
#
#                                   Store Name              Address  \
# 0                         Dahl's / Merle Hay  4343 MERLE HAY ROAD
# 1                Liquor and Tobacco Outlet /     620 W Bremer Ave
# 2       Casey's General Store #1941 / Ankeny  1010 SE Oralabor Rd
# ...

# %%
## List of columns in dataset

random_liq_subset.columns
# Out:
# Index(['Invoice/Item Number', 'Date', 'Store Number', 'Store Name', 'Address',
#        'City', 'Zip Code', 'Store Location', 'County Number', 'County',
#        'Category', 'Category Name', 'Vendor Number', 'Vendor Name',
#        'Item Number', 'Item Description', 'Pack', 'Bottle Volume (ml)',
#        'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold',
#        'Sale (Dollars)', 'Volume Sold (Liters)', 'Volume Sold (Gallons)'],
#       dtype='object')

# %%
import seaborn as sns

sns.kdeplot(random_liq_subset['Sale (Dollars)'],bw = 500, cut = 0)
# Out:
# C:\Users\rauna\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 500 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sale (Dollars)', ylabel='Density'>

# %%
df.head()
# Out:
#   Item Number                 Category Name  \
# 0      901141           Special Order Items
# 1       65017  Imported Cordials & Liqueurs
# 2       88152            100% Agave Tequila
# 3      903796           Special Order Items
# 4      905846               Scotch Whiskies
#
#                            Item Description  Vendor  \
# 0  Libertine Absinthe(French Absinthe) Mini     885
# 1                          Galliano Liqueur     305
# 2                          Sauza 901 Silver      65
# 3                       Bacardi Anejo DISCO      35
# 4                              Ron Burgundy     305
#
#                  Vendor Name  Bottle Volume (ml)  Pack  Inner Pack  Age  \
# 0  YAHARA BAY DISTILLERS INC                  50     6           1    0
# 1                    Mhw LTD                 375    12           1    0
# 2            Jim Beam Brands                 750     6           1    0
# 3            BACARDI USA INC                 750    12           1    0
# ...

# %%
nullvalues = df.isnull().sum(axis=0).sort_values(ascending=False)
nullvalues
# Out:
# UPC                    1
# Item Number            0
# Category Name          0
# Report Date            0
# State Bottle Retail    0
# State Case Cost        0
# State Bottle Cost      0
# SCC                    0
# List Date              0
# Proof                  0
# Age                    0
# Inner Pack             0
# Pack                   0
# Bottle Volume (ml)     0
# Vendor Name            0
# Vendor                 0
# Item Description       0
# Profit Per Bottle      0
# dtype: int64

# %%
#create profit per bottle
df['Profit Per Bottle'] = df['State Bottle Retail'] - df['State Bottle Cost']

# %%
df.columns
# Out:
# Index(['Item Number', 'Category Name', 'Item Description', 'Vendor',
#        'Vendor Name', 'Bottle Volume (ml)', 'Pack', 'Inner Pack', 'Age',
#        'Proof', 'List Date', 'UPC', 'SCC', 'State Bottle Cost',
#        'State Case Cost', 'State Bottle Retail', 'Report Date',
#        'Profit Per Bottle'],
#       dtype='object')

# %%
products =df[["Item Number",'Category Name','Bottle Volume (ml)','Pack','Age','Proof','State Bottle Cost',
       'State Case Cost', 'State Bottle Retail', 'Profit Per Bottle']]

# %%
products.head()
# Out:
#   Item Number                 Category Name  Bottle Volume (ml)  Pack  Age  \
# 0      901141           Special Order Items                  50     6    0
# 1       65017  Imported Cordials & Liqueurs                 375    12    0
# 2       88152            100% Agave Tequila                 750     6    0
# 3      903796           Special Order Items                 750    12    0
# 4      905846               Scotch Whiskies                 750    12    0
#
#    Proof  State Bottle Cost  State Case Cost  State Bottle Retail  \
# 0    114               4.82            28.90                 7.23
# 1     84              10.75           129.00                16.13
# 2     80              13.12            78.72                19.68
# 3     80               7.75            93.00                11.63
# 4     80              14.61           175.25                21.92
#
#    Profit Per Bottle
# 0               2.41
# 1               5.38
# 2               6.56
# 3               3.88
# ...
